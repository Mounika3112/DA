# %%
print("hekllo")
# Out:
# hekllo

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("Adidas_USSales_Datasets.xlsx")

# %%
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
df.groupby(['Retailer'])['Retailer ID'].unique()
# Out:
# Retailer
# Amazon                                      [1185732]
# Foot Locker               [1185732, 1128299, 1197831]
# Kohl's           [1189833, 1185732, 1128299, 1197831]
# Sports Direct             [1197831, 1185732, 1128299]
# Walmart                   [1185732, 1197831, 1128299]
# West Gear                 [1128299, 1185732, 1197831]
# Name: Retailer ID, dtype: object

# %%
df.groupby(['Region'])['Retailer'].unique()
# Out:
# Region
# Midwest      [Foot Locker, Sports Direct, Kohl's, West Gear...
# Northeast    [Foot Locker, Walmart, Sports Direct, West Gea...
# South        [Sports Direct, Walmart, West Gear, Foot Locke...
# Southeast    [Foot Locker, West Gear, Sports Direct, Walmar...
# West         [West Gear, Kohl's, Foot Locker, Amazon, Walma...
# Name: Retailer, dtype: object

# %%
df.groupby(['City'])['Retailer'].unique()
# Out:
# City
# Albany                                [West Gear, Kohl's]
# Albuquerque                       [Kohl's, Sports Direct]
# Anchorage                           [Amazon, Foot Locker]
# Atlanta                      [Sports Direct, Foot Locker]
# Baltimore         [West Gear, Foot Locker, Sports Direct]
# Billings                          [Kohl's, Sports Direct]
# Birmingham                        [Sports Direct, Amazon]
# Boise             [Foot Locker, West Gear, Sports Direct]
# Boston                            [Sports Direct, Amazon]
# Burlington                            [Amazon, West Gear]
# Charleston        [Foot Locker, Sports Direct, West Gear]
# Charlotte                         [Sports Direct, Amazon]
# Cheyenne                            [Kohl's, Foot Locker]
# Chicago                      [Foot Locker, Sports Direct]
# Columbus                              [Amazon, West Gear]
# Dallas                       [Sports Direct, Foot Locker]
# ...

# %%
df.groupby(['City'])['Product'].unique()
# Out:
# City
# Albany            [Women's Athletic Footwear, Men's Apparel, Wom...
# Albuquerque       [Women's Athletic Footwear, Men's Apparel, Wom...
# Anchorage         [Women's Apparel, Men's Street Footwear, Men's...
# Atlanta           [Women's Athletic Footwear, Men's Apparel, Wom...
# Baltimore         [Women's Athletic Footwear, Men's Apparel, Wom...
# Billings          [Men's Apparel, Women's Apparel, Men's Street ...
# Birmingham        [Men's Apparel, Women's Apparel, Men's Street ...
# Boise             [Women's Athletic Footwear, Men's Apparel, Wom...
# Boston            [Women's Athletic Footwear, Men's Apparel, Wom...
# Burlington        [Women's Athletic Footwear, Men's Apparel, Wom...
# Charleston        [Women's Athletic Footwear, Men's Apparel, Wom...
# Charlotte         [Women's Athletic Footwear, Men's Apparel, Wom...
# Cheyenne          [Women's Athletic Footwear, Men's Apparel, Wom...
# Chicago           [Men's Apparel, Women's Apparel, Men's Street ...
# ...

# %%
df.groupby(['Retailer'])['Total Sales'].sum()
# Out:
# Retailer
# Amazon            77698912.0
# Foot Locker      220094720.0
# Kohl's           102114753.0
# Sports Direct    182470997.0
# Walmart           74558410.0
# West Gear        242964333.0
# Name: Total Sales, dtype: float64

# %%
df.groupby(['City','Retailer']).aggregate({'Total Sales':sum,'Operating Profit':sum})
# Out:
#                            Total Sales  Operating Profit
# City        Retailer
# Albany      Kohl's           3692639.0        1367451.11
#             West Gear       20735165.0        8062399.80
# Albuquerque Kohl's          17065965.0        5783668.15
#             Sports Direct    2799051.0         954392.26
# Anchorage   Amazon          13365025.0        4143804.75
# ...                                ...               ...
# St. Louis   West Gear        1701133.0         681457.25
# Wichita     Foot Locker      3520950.0        1230372.67
#             Kohl's           6451914.0        2279774.62
# Wilmington  Foot Locker      8387568.0        3077352.68
#             Kohl's           3910844.0        1446997.38
#
# [108 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
df.groupby(['Product','Retailer']).aggregate({'Total Sales':sum,'Operating Profit':sum})
# Out:
#                                          Total Sales  Operating Profit
# Product                   Retailer
# Men's Apparel             Amazon          10474770.0        3331443.80
#                           Foot Locker     29508995.0        9942404.61
#                           Kohl's          14164965.0        5945043.20
#                           Sports Direct   24825286.0        8723914.71
#                           Walmart         11490680.0        3166591.22
#                           West Gear       33263936.0       13653632.79
# Men's Athletic Footwear   Amazon          12011959.0        4518030.11
#                           Foot Locker     36480415.0       12409221.49
#                           Kohl's          17885316.0        5725762.60
#                           Sports Direct   30889734.0       11935672.81
#                           Walmart         13600404.0        4029257.65
#                           West Gear       42805852.0       13228943.53
# ...
